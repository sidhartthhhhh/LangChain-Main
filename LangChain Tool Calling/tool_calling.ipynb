# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
# model creation
model = ChatGoogleGenerativeAI(model="gemini-2.0-flash")

# %%
# tool creation
@tool
def multiply(a: int,b: int)->int:
    """Given 2 numbers a and b this tool return their product"""
    return a * b

# %%
# tool binding
llm_with_tool = model.bind_tools([multiply])

# %%
llm_with_tool.invoke("how are you")
# Out:
# AIMessage(content='I am doing well, thank you for asking. How can I help you today?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--e48ffc2d-1402-445f-ab56-3ab9f3070460-0', usage_metadata={'input_tokens': 23, 'output_tokens': 18, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}})

# %%
query = HumanMessage('Can you multiply 3 with 10')

# %%
messages = [query]

# %%
messages
# Out:
# [HumanMessage(content='Can you multiply 3 with 10', additional_kwargs={}, response_metadata={})]

# %%
result = llm_with_tool.invoke(messages)

# %%
messages.append(result)

# %%
messages
# Out:
# [HumanMessage(content='Can you multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"a": 3.0, "b": 10.0}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--380c99fa-aac0-48ff-82b0-58c92b1f0cbf-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3.0, 'b': 10.0}, 'id': '366f515a-e417-41ef-ba21-891c8be6b0b7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 29, 'output_tokens': 5, 'total_tokens': 34, 'input_token_details': {'cache_read': 0}})]

# %%
tool_result = multiply.invoke(result.tool_calls[0])

# %%
messages.append(tool_result)

# %%
messages
# Out:
# [HumanMessage(content='Can you multiply 3 with 10', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='', additional_kwargs={'function_call': {'name': 'multiply', 'arguments': '{"a": 3.0, "b": 10.0}'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': []}, id='run--380c99fa-aac0-48ff-82b0-58c92b1f0cbf-0', tool_calls=[{'name': 'multiply', 'args': {'a': 3.0, 'b': 10.0}, 'id': '366f515a-e417-41ef-ba21-891c8be6b0b7', 'type': 'tool_call'}], usage_metadata={'input_tokens': 29, 'output_tokens': 5, 'total_tokens': 34, 'input_token_details': {'cache_read': 0}}),
#  ToolMessage(content='30', name='multiply', tool_call_id='366f515a-e417-41ef-ba21-891c8be6b0b7')]

# %%
llm_with_tool.invoke(messages).content
# Out:
# 'The product of 3 and 10 is 30.'
